# %% [markdown]
# <a href="https://colab.research.google.com/github/DaoOfDreams/CosmicDreamers_AppDevelopment_Rookies/blob/main/DAV_Exp11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 import pandas as pd

# %%
df_ENE = pd.read_excel("/content/Yearly Demand Profile_E_NE.xlsx")
df_NS = pd.read_excel("/content/Yearly Demand Profile_N_S.xlsx")
df_WS = pd.read_excel("/content/Yearly Demand Profile_W_S.xlsx")

# %%
df_ENE.head()
# Out:
#                   Region         Date  Hourly Demand Met (in MW)
# 0  Eastern Region - 2022  01-Jan 12am                   15296.30
# 1  Eastern Region - 2022   01-Jan 1am                   14759.29
# 2  Eastern Region - 2022   01-Jan 2am                   14407.11
# 3  Eastern Region - 2022   01-Jan 3am                   14200.25
# 4  Eastern Region - 2022   01-Jan 4am                   14406.90

# %%
Yearly_demand_df = pd.concat([df_ENE, df_NS, df_WS], ignore_index=True)
Yearly_demand_df.head()
# Out:
#                   Region         Date  Hourly Demand Met (in MW)
# 0  Eastern Region - 2022  01-Jan 12am                   15296.30
# 1  Eastern Region - 2022   01-Jan 1am                   14759.29
# 2  Eastern Region - 2022   01-Jan 2am                   14407.11
# 3  Eastern Region - 2022   01-Jan 3am                   14200.25
# 4  Eastern Region - 2022   01-Jan 4am                   14406.90

# %%
Yearly_demand_df.shape
# Out:
# (52572, 3)

# %%
Yearly_demand_df['Date'] = '2022 ' + Yearly_demand_df['Date']
Yearly_demand_df['Date'] = pd.to_datetime(Yearly_demand_df['Date'], format='%Y %d-%b %I%p')
Yearly_demand_df.head()
# Out:
#                   Region                Date  Hourly Demand Met (in MW)
# 0  Eastern Region - 2022 2022-01-01 00:00:00                   15296.30
# 1  Eastern Region - 2022 2022-01-01 01:00:00                   14759.29
# 2  Eastern Region - 2022 2022-01-01 02:00:00                   14407.11
# 3  Eastern Region - 2022 2022-01-01 03:00:00                   14200.25
# 4  Eastern Region - 2022 2022-01-01 04:00:00                   14406.90

# %%
import folium

# %%
def get_coordinates(region):
    region_coordinates = {
      'Eastern Region - 2022': (23.684994, 86.952393),
      'Western Region - 2022': (22.814, 72.507),
      'Northern Region - 2022': (29.0588, 76.0856),
      'Southern Region - 2022': (11.1271, 78.6569),
      'North-Eastern Region - 2022': (26.2006, 92.9376)
    }
    return region_coordinates.get(region, (0, 0))

# %%
india_map = folium.Map(location=[20.5937, 78.9629], zoom_start=5)

# %%
for index, row in Yearly_demand_df.iterrows():
    folium.Marker(
        location=get_coordinates(row['Region']),
        popup=f"Region: {row['Region']}\nDate: {row['Date']}\nHourly Demand: {row['Hourly Demand Met (in MW)']}",
        icon=folium.Icon(color='blue', icon='info-sign')
    ).add_to(india_map)

# Display the map
india_map.save('energy_demand_map.html')

# %%
library(readxl)

# %%
Yearly_demand_MAH_GUJ <- read_excel("/content/Yearly Demand Profile_MAH-GUJ.xlsx")
head(Yearly_demand_MAH_GUJ)
# Out:
#   State              Date        Hourly Demand Met (in MW)
# 1 Maharashtra - 2022 01-Jan 12am 15783.14
# 2 Maharashtra - 2022 01-Jan 1am  15788.36
# 3 Maharashtra - 2022 01-Jan 2am  15636.04
# 4 Maharashtra - 2022 01-Jan 3am  15835.21
# 5 Maharashtra - 2022 01-Jan 4am  15907.30
# 6 Maharashtra - 2022 01-Jan 5am  16724.21

# %%
Yearly_Demand_Profile_MAH <- Yearly_demand_MAH_GUJ[grepl("Maharashtra",Yearly_demand_MAH_GUJ$State), ]

# %%
Yearly_Demand_Profile_MAH$Date <- strptime(Yearly_Demand_Profile_MAH$Date, format = "%d-%b %I%p")
# Yearly_Demand_Profile_MAH$Date$year <- 2022 - 1900
# df.e1 <- Yearly_Demand_Profile_MAH
head(Yearly_Demand_Profile_MAH)
# Out:
#   State              Date                Hourly Demand Met (in MW)
# 1 Maharashtra - 2022 2024-01-01 00:00:00 15783.14
# 2 Maharashtra - 2022 2024-01-01 01:00:00 15788.36
# 3 Maharashtra - 2022 2024-01-01 02:00:00 15636.04
# 4 Maharashtra - 2022 2024-01-01 03:00:00 15835.21
# 5 Maharashtra - 2022 2024-01-01 04:00:00 15907.30
# 6 Maharashtra - 2022 2024-01-01 05:00:00 16724.21
